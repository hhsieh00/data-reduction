# %%
# %matplotlib inline
import os, sys
#sys.path.append('/Users/hhsieh/opt/anaconda3/envs/astroconda/lib/python3.7/site-packages')
#sys.path.append('/opt/local/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages')
print(sys.version)
print('')
import matplotlib.pyplot as plt
from astropy.io import fits
from astropy.io.fits import getheader
from astropy.modeling import models
from astropy import nddata
from astropy import units as u
import ccdproc as cp
from ccdproc import CCDData, ImageFileCollection
import numpy as np
import glob, os, bz2, subprocess
import sqlite3
from sqlite3 import Error
import datetime
# Out:
# 3.7.13 (default, Mar 28 2022, 07:24:34)
# [Clang 12.0.0 ]

# %%
def create_directory(path):
    if not os.path.exists(path):
        os.mkdir(path)
        print('Directory {:s} successfully created.'.format(path))
    else:
        print('Directory {:s} already exists.'.format(path))
    return None

def decompress_file_bzip2(filename):
    cmd = ['bzip2','-d',filename]
    process = subprocess.call(cmd)
    return None

def compress_file_fpack(filename):
    fpack_command  = '/Users/hhsieh/Astro/tools/cfitsio/fpack'
    delete_command = '/bin/rm'
    fpack_cmd = [fpack_command,filename]
    process = subprocess.call(fpack_cmd)
    delete_cmd = [delete_command,filename]
    process = subprocess.call(delete_cmd)
    return None

def decompress_file_fpack(filename):
    funpack_command = '/Users/hhsieh/Astro/tools/cfitsio/funpack'
    delete_command  = '/bin/rm'
    funpack_cmd = [funpack_command,filename]
    process = subprocess.call(funpack_cmd)
    delete_cmd = [delete_command,filename]
    process = subprocess.call(delete_cmd)
    return None

def decompress_directory_bzip2(file_path):
    print('>>> Starting decompression of bz2 files in {:s}...'.format(file_path))
    os.chdir(file_path)
    for bz2_file in glob.glob('*.bz2'):
        decompress_file_bzip2(bz2_file)
        #cmd = [bzip1,bzip2,bz2_file]
        #process = subprocess.call(cmd)
    print('>>> Decompression of bz2 files complete.')
    return None

def compress_directory_fpack(file_path):
    print('>>> Starting fpack compression of FITS files in {:s}...'.format(file_path))
    #fpack_file = '/Users/hhsieh/Astro/tools/cfitsio/fpack'
    #delete_file = '/bin/rm'
    os.chdir(file_path)
    for fits_file in glob.glob('*.fits'):
        compress_file_fpack(fits_file)
        #fpack_cmd = [fpack_file,fits_file]
        #process = subprocess.call(fpack_cmd)
        #delete_cmd = [delete_file,fits_file]
        #process = subprocess.call(delete_cmd)
    print('>>> fpack compression of FITS files complete.')
    return None
    
def decompress_directory_fpack(file_path):
    print('>>> Starting decompression of fz files in {:s}...'.format(file_path))
    #funpack_file = '/Users/hhsieh/Astro/tools/cfitsio/funpack'
    #delete_file = '/bin/rm'
    os.chdir(file_path)
    for fz_file in glob.glob('*.fz'):
        decompress_file_fpack(fz_file)
        #funpack_cmd = [funpack_file,fz_file]
        #process = subprocess.call(funpack_cmd)
        #delete_cmd = [delete_file,fz_file]
        #process = subprocess.call(delete_cmd)
    print('>>> Decompression of fz files complete.')
    return None


#def decompress_data_bzip2():
#    print('>>> Starting decompression of bz2 files...')
#    bzip1 = 'bzip2'
#    bzip2 = '-d'
#    for bz2_file in glob.glob('*.bz2'):
#        cmd = [bzip1,bzip2,bz2_file]
#        process = subprocess.call(cmd)
#    print('>>> Decompression of bz2 files complete.')
#
#def decompress_data_fpack():
#    print('>>> Starting decompression of fz files...')
#    funpack_file = '/Users/hhsieh/Astro/tools/cfitsio/funpack'
#    delete_file = '/bin/rm'
#    for fz_file in glob.glob('*.fz'):
#        funpack_cmd = [funpack_file,fz_file]
#        process = subprocess.call(funpack_cmd)
#        delete_cmd = [delete_file,fz_file]
#        process = subprocess.call(delete_cmd)
#    print('>>> Decompression of fz files complete.')
#
#def compress_data_fpack():
#    print('>>> Starting fpack compression of fits files...')
#    fpack_file = '/Users/hhsieh/Astro/tools/cfitsio/fpack'
#    delete_file = '/bin/rm'
#    for fits_file in glob.glob('*.fits'):
#        fpack_cmd = [fpack_file,fits_file]
#        process = subprocess.call(fpack_cmd)
#        delete_cmd = [delete_file,fits_file]
#        process = subprocess.call(delete_cmd)
#    print('>>> Compression of fits files complete.')

def get_date_id():
    # obtain YYYYMMDD date from filename of GMOS FITS files being processed
    # return: YYYYMMDD date id
    for raw_mef_file in glob.glob('*.fits'):
        fits_date = raw_mef_file[1:9]
    return fits_date

def create_stats_files(fits_date):
    for extid in range(2,10):
        ext_stats = 'n' + fits_date + '.{:02d}.stats'.format(extid+1)
        outputfile = open(ext_stats,'w')
        outputfile.write('# Extension {:02d}              NPIX        MEAN     STDDEV         MIN         MAX\n'.format(extid+1))
        outputfile.close()
        
def compile_stats_files(fits_date,outputfile_path):
    print('Starting image statistics output...')
    output_stats_filename = outputfile_path + 'n' + fits_date + '.stats'
    output_stats_file = open(output_stats_filename,'w')
    cmd1 = '/bin/rm'
    for stats_filename in glob.glob('*.??.stats'):
        stats_file = open(stats_filename,'r')
        for line in stats_file:
            output_stats_file.write(line)
        stats_file.close()
        cmd = [cmd1,stats_filename]
        process = subprocess.call(cmd)
    output_stats_file.close()
    print('>>> Image statistics output complete.')

def split_extensions():
    # split 12-element GMOS multi-extension FITS files into individual elements
    # return: dimensions of extensions; also writes individual extension files to working directory
    for raw_mef_file in glob.glob('*.fits'):
        hdulist = fits.open(raw_mef_file)
        print('Splitting {:s}...'.format(raw_mef_file))
        fits_date = raw_mef_file[1:9]
        fits_id   = raw_mef_file[11:14]
        hdr1 = getheader(raw_mef_file,0)
        for extid in range(2,10):
            extension = hdulist[extid+1].data
            hdr2 = hdulist[extid+1].header
            radecsys = hdr2['RADECSYS']
            hdr2['RADESYSA'] = radecsys
            del hdr2['RADECSYS']
            imstat_npix = extension.size
            imstat_min = np.min(extension)
            imstat_max = np.max(extension)
            imstat_mean = np.mean(extension)
            imstat_stdev = np.std(extension)
            ext_filename = 'n' + fits_date + '.' + fits_id + '.{:02d}.fits'.format(extid+1)
            outputfilename = 'n' + fits_date + '.{:02d}.stats'.format(extid+1)
            outputfile = open(outputfilename,'a')
            outputfile.write('{:s}   {:>8d}    {:>8.2f}    {:>7.2f}    {:>8.2f}    {:>8.2f}\n'.format(ext_filename,imstat_npix,imstat_mean,imstat_stdev,imstat_min,imstat_max))
            outputfile.close()
            dimensions = extension.shape
            dimension1 = dimensions[0]
            dimension2 = dimensions[1]
            hdr = hdr1 + hdr2
            fits.writeto(ext_filename,extension,hdr)
        hdulist.close()
    return dimension1, dimension2
    print('>>> Multi-extension fits file splitting complete.')


def remove_wrong_dimensions(dimension1,dimension2):
    # identify bias files with correct binning and remove others
    # return: none; retains bias files with correct binning and removes others
    for raw_mef_file in glob.glob('*.fits'):
        hdulist = fits.open(raw_mef_file)
        extension01 = hdulist[1].data
        bias_dimensions = extension01.shape
        bias_dimension1 = bias_dimensions[0]
        bias_dimension2 = bias_dimensions[1]
        hdulist.close()
        delete_file = '/bin/rm'
        if (bias_dimension1 != dimension1) or (bias_dimension2 != dimension2):
            delete_cmd = [delete_file,raw_mef_file]
            process = subprocess.call(delete_cmd)
    print('>>> Bias frame selection complete.')

def overscan_and_trim():
    # Do overscan correction and trim images in current directory
    print('Starting overscan correction and trimming...')
    for fits_file in glob.glob('*.???.??.fits'):
        ot_fits_file = fits_file[0:16] + '.ot.fits'
        fits_data = CCDData.read(fits_file,unit=u.adu)
        file_ext = fits_file[14:16]
        # Overscan correction
        if ((file_ext == '03') or (file_ext=='05') or (file_ext=='07') or (file_ext=='09')):
            o_fits_data  = cp.subtract_overscan(fits_data, fits_section='[257:288,1:2112]', overscan_axis=1, add_keyword={'oscansub': True, 'calstat': 'O'}, model=models.Polynomial1D(1))
        else:
            o_fits_data  = cp.subtract_overscan(fits_data, fits_section='[1:32,1:2112]', overscan_axis=1, add_keyword={'oscansub': True, 'calstat': 'O'}, model=models.Polynomial1D(1))
        # Image trimming
        if ((file_ext == '03') or (file_ext=='07')):
            ot_fits_data = cp.trim_image(o_fits_data,fits_section='[1:256,65:2110]',add_keyword={'trimmed': True, 'calstat': 'OT'})
        elif ((file_ext == '04') or (file_ext == '08')):
            ot_fits_data = cp.trim_image(o_fits_data,fits_section='[33:282,65:2110]',add_keyword={'trimmed': True, 'calstat': 'OT'})
        elif ((file_ext == '05') or (file_ext =='09')):
            ot_fits_data = cp.trim_image(o_fits_data,fits_section='[7:256,65:2110]',add_keyword={'trimmed': True, 'calstat': 'OT'})
        else: # file_ext == '02' or file_ext == '10'
            ot_fits_data = cp.trim_image(o_fits_data,fits_section='[33:288,65:2110]',add_keyword={'trimmed': True, 'calstat': 'OT'})
        ot_fits_data.write(ot_fits_file)
        delete_file = '/bin/rm'
        delete_cmd = [delete_file,fits_file]
        process = subprocess.call(delete_cmd)
    print('>>> Overscan correction and trimming complete.')
    return None

def bias_median_combine(dateid):
    print('Starting median combination of bias frames...')
    for extid in range(2,10):
        bias_list = []
        ext_file_format = '*.{:02d}.ot.fits'.format(extid+1)
        output_filename = 'n' + dateid + '.bias.{:02d}.fits'.format(extid+1)
        for fits_file in glob.glob(ext_file_format):
            fits_data = CCDData.read(fits_file)
            bias_list.append(fits_data)
            delete_file = '/bin/rm'
            delete_cmd = [delete_file,fits_file]
            process = subprocess.call(delete_cmd)
        master_bias = cp.combine(bias_list,method='median')
        master_bias.write(output_filename)
    print('>>> Median combination of bias frames complete.')

def bias_correct(dateid,cwd_raw_bias):
    print('Starting bias subtraction...')
    delete_cmd = '/bin/rm'
    for extid in range(2,10):
        bias_filename = cwd_raw_bias + 'n' + dateid + '.bias.{:02d}.fits'.format(extid+1)
        ext_file_format = '*.{:02d}.ot.fits'.format(extid+1)
        for fits_file in glob.glob(ext_file_format):
            fits_data = CCDData.read(fits_file)
            bias_data = CCDData.read(bias_filename)
            fits_date_imageid = fits_file[0:13]
            output_filename = fits_date_imageid + '.{:02d}.otz.fits'.format(extid+1)
            bias_corrected_data = cp.subtract_bias(fits_data,bias_data,add_keyword={'zerocorr': True, 'calstat': 'OTZ'})
            bias_corrected_data.write(output_filename)
            delete_file = [delete_cmd,fits_file]
            process = subprocess.call(delete_file)
    print('>>> Bias subtraction complete.')
    return None
    
def concatenate_gmos_amps():
    print('>>> Starting adjacent amp area concatenation...')
    delete_cmd = '/bin/rm'
    for fits_file in glob.glob('*.03.otz.fits'):
        file_prefix = fits_file[0:13]
        ext1_filename = file_prefix + '.03.otz.fits'
        ext2_filename = file_prefix + '.04.otz.fits'
        hdr = getheader(ext1_filename,0)
        hdulist1 = fits.open(ext1_filename)
        ext1_data = hdulist1[0].data
        hdulist2 = fits.open(ext2_filename)
        ext2_data = hdulist2[0].data
        hdulist1.close()
        hdulist2.close()
        chip1_data = np.hstack((ext1_data,ext2_data))
        output_filename = file_prefix + '.chip1.otz.fits'
        fits.writeto(output_filename,chip1_data,hdr)
        delete_file = [delete_cmd,ext1_filename]
        process = subprocess.call(delete_file)
        delete_file = [delete_cmd,ext2_filename]
        process = subprocess.call(delete_file)

        ext1_filename = file_prefix + '.05.otz.fits'
        ext2_filename = file_prefix + '.06.otz.fits'
        ext3_filename = file_prefix + '.07.otz.fits'
        ext4_filename = file_prefix + '.08.otz.fits'
        hdr = getheader(ext1_filename,0)
        hdulist1 = fits.open(ext1_filename)
        ext1_data = hdulist1[0].data
        hdulist2 = fits.open(ext2_filename)
        ext2_data = hdulist2[0].data
        hdulist3 = fits.open(ext3_filename)
        ext3_data = hdulist3[0].data
        hdulist4 = fits.open(ext4_filename)
        ext4_data = hdulist4[0].data
        hdulist1.close()
        hdulist2.close()
        hdulist3.close()
        hdulist4.close()
        chip1_data = np.hstack((ext1_data,ext2_data,ext3_data,ext4_data))
        output_filename = file_prefix + '.chip2.otz.fits'
        fits.writeto(output_filename,chip1_data,hdr)
        delete_file = [delete_cmd,ext1_filename]
        process = subprocess.call(delete_file)
        delete_file = [delete_cmd,ext2_filename]
        process = subprocess.call(delete_file)
        delete_file = [delete_cmd,ext3_filename]
        process = subprocess.call(delete_file)
        delete_file = [delete_cmd,ext4_filename]
        process = subprocess.call(delete_file)

        ext1_filename = file_prefix + '.09.otz.fits'
        ext2_filename = file_prefix + '.10.otz.fits'
        hdr = getheader(ext1_filename,0)
        hdulist1 = fits.open(ext1_filename)
        ext1_data = hdulist1[0].data
        hdulist2 = fits.open(ext2_filename)
        ext2_data = hdulist2[0].data
        hdulist1.close()
        hdulist2.close()
        chip1_data = np.hstack((ext1_data,ext2_data))
        output_filename = file_prefix + '.chip3.otz.fits'
        fits.writeto(output_filename,chip1_data,hdr)
        delete_file = [delete_cmd,ext1_filename]
        process = subprocess.call(delete_file)
        delete_file = [delete_cmd,ext2_filename]
        process = subprocess.call(delete_file)
    print('>>> Adjacent amp area concatenation complete.')


def process_flatfield_files(path_rawfits,path_rawbias,path_procfits):
    
    print('\n')
    create_directory(path_procfits)
    
    # Process raw science fits files
    print('\n{:s} - Decompressing and splitting data files...'.format(datetime.datetime.today().strftime('%Y-%m-%d %H:%M:%S')))
    os.chdir(path_rawfits)
    decompress_directory_bzip2(path_rawfits)      #decompress downloaded GMOS files
    decompress_directory_fpack(path_rawfits)      #decompress previously fpacked GMOS files
    date_id = get_date_id()
    create_stats_files(date_id)                   #create files to record image statistics of bias files
    dim1,dim2 = split_extensions()                #split science MEFs into individual FITS files
    compile_stats_files(date_id,path_procfits)                  #collect image statistics of science files together and delete individual files

    # decompress raw bias fits files
    print('\n{:s} - Decompressing, filtering, and splitting bias files...'.format(datetime.datetime.today().strftime('%Y-%m-%d %H:%M:%S')))
    os.chdir(path_rawbias)
    decompress_directory_bzip2(path_rawbias)      #decompress downloaded GMOS files
    decompress_directory_fpack(path_rawbias)      #decompress previously fpacked GMOS files
    remove_wrong_dimensions(dim1,dim2)            #find and retain bias frames matching data file binning
    create_stats_files(date_id)                   #create files to record image statistics of bias files
    split_extensions()                            #split bias MEFs into individual FITS files
    compile_stats_files(date_id+'.bias',path_procfits)          #collect image statistics of bias files together and delete individual files

    # perform overscan corrections and trim data for bias frames
    os.chdir(path_rawbias)
    overscan_and_trim()
    bias_median_combine(date_id)

    # perform overscan corrections and trim data for science frames
    os.chdir(path_rawfits)
    overscan_and_trim()
    bias_correct(date_id,path_rawbias)

    # join science frames
    os.chdir(path_rawfits)
    concatenate_gmos_amps()
    
    # move processed files to processed directory
    os.chdir(path_rawfits)
    for fits_file in glob.glob('*.chip?.otz.fits'):
        cmd_mv = 'mv'
        move_file_to_flat_dir = [cmd_mv,fits_file,path_procfits]
        process = subprocess.call(move_file_to_flat_dir)
    os.chdir(path_rawbias)
    for fits_file in glob.glob('*.bias.??.fits'):
        cmd_mv = 'mv'
        move_file_to_flat_dir = [cmd_mv,fits_file,path_procfits]
        process = subprocess.call(move_file_to_flat_dir)

    #os.chdir(path_rawfits)
    compress_directory_fpack(path_rawfits)
    #os.chdir(path_rawbias)
    compress_directory_fpack(path_rawbias)
    #os.chdir(path_procfits)
    compress_directory_fpack(path_procfits)
        
    return None
        
print('Done.')
# Out:
# Done.

# %%
def process_flatfield_directories(basewd):
    os.chdir(basewd)
    rawfits_dir   = '/rawfits_twiskyflat/'
    rawbias_dir   = '/rawfits_bias/'
    procfits_dir  = '/procfits_twiskyflat/'

    for datadir in glob.glob('ut*_gemini?_twiskyflat'):
        path_rawfits  = basewd + datadir + rawfits_dir
        path_rawbias  = basewd + datadir + rawbias_dir
        path_procfits = basewd + datadir + procfits_dir
    
        if not os.path.exists(path_procfits):    
            if os.path.exists(path_rawfits):
                if os.path.exists(path_rawbias):
                    if len(os.listdir(path_rawfits)) > 0:
                        if len(os.listdir(path_rawbias)) > 0:
                            process_flatfield_files(path_rawfits,path_rawbias,path_procfits)
                        else:
                            print('{:s} - Bias directory in {:s} is empty.'.format(datetime.datetime.today().strftime('%Y-%m-%d %H:%M:%S'),datadir))
                    else:
                        print('{:s} - Raw flatfield directory in {:s} is empty.'.format(datetime.datetime.today().strftime('%Y-%m-%d %H:%M:%S'),datadir))
                else:
                    print('{:s} - Bias directory ({:s}) not found.'.format(datetime.datetime.today().strftime('%Y-%m-%d %H:%M:%S'),datadir))
            else:
                print('{:s} - Raw flatfield directory ({:s}) not found.'.format(datetime.datetime.today().strftime('%Y-%m-%d %H:%M:%S'),datadir))
        else:
            print('{:s} - Data in {:s} already processed.'.format(datetime.datetime.today().strftime('%Y-%m-%d %H:%M:%S'),datadir))

    return None

# %%
process_flatfield_directories('/volumes/Fantom12a/BackupData/gemini/data_calib/GMOS-N_TwilightFlats_20170301_present/GMOS-N_Twilight_Flats_g/')
process_flatfield_directories('/volumes/Fantom12a/BackupData/gemini/data_calib/GMOS-N_TwilightFlats_20170301_present/GMOS-N_Twilight_Flats_r/')
process_flatfield_directories('/volumes/Fantom12a/BackupData/gemini/data_calib/GMOS-N_TwilightFlats_20170301_present/GMOS-N_Twilight_Flats_i/')
process_flatfield_directories('/volumes/Fantom12a/BackupData/gemini/data_calib/GMOS-N_TwilightFlats_20170301_present/GMOS-N_Twilight_Flats_z/')
process_flatfield_directories('/volumes/Fantom12a/BackupData/gemini/data_calib/GMOS-S_TwilightFlats_20150101_present/GMOS-S_Twilight_Flats_g/')
process_flatfield_directories('/volumes/Fantom12a/BackupData/gemini/data_calib/GMOS-S_TwilightFlats_20150101_present/GMOS-S_Twilight_Flats_r/')
process_flatfield_directories('/volumes/Fantom12a/BackupData/gemini/data_calib/GMOS-S_TwilightFlats_20150101_present/GMOS-S_Twilight_Flats_i/')
process_flatfield_directories('/volumes/Fantom12a/BackupData/gemini/data_calib/GMOS-S_TwilightFlats_20150101_present/GMOS-S_Twilight_Flats_z/')

print('Done.')
# Out:
# 2023-02-26 08:43:38 - Data in ut20170406_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20170411_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20170424_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20170427_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20170627_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20170628_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20170828_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20171004_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20171005_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20171030_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20180113_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20180512_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20180621_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20180623_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20180729_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20180812_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20180916_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20181022_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20181027_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20181102_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20181108_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20190107_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20190204_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20190309_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20190322_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20190512_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20190524_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20190612_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20190625_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20190906_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20190907_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20191103_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20191105_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20191231_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20200102_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20200202_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20200227_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20200603_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20200604_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20200608_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20200623_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20200803_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20200812_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20200813_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20200903_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20200904_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20200913_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20200915_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20201018_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20201128_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20201225_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20210202_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20210210_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20210306_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20210515_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20210602_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20210611_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20210710_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20211007_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20211026_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20211028_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20211126_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20211127_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20211214_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20220122_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20220301_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20220305_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20220510_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20170323_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20170402_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20170408_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20170410_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20170425_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20170507_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20170524_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20170621_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20170625_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20170901_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20170902_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20170904_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20170906_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20170921_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20170925_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20171028_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20171029_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20180117_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20180318_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20180424_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20180426_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20180521_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20180603_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20180606_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20180719_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20180818_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20180915_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20181001_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20181011_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20181017_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20181106_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20181115_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20190105_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20190106_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20190127_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20190226_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20190315_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20190325_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20190424_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20190425_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20190527_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20190614_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20190705_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20190707_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20190903_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20191105_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20191115_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20200101_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20200118_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20200119_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20200130_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20200131_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20200220_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20200224_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20200525_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20200605_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20200617_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20200624_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20200628_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20200729_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20200816_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20200903_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20200906_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20200910_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20200912_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20200928_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20200929_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20201003_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20201010_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20201114_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20201117_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20201126_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20201224_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20201226_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20210118_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20210129_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20210210_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20210303_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20210304_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20210414_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20210416_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20210418_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20210503_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20210504_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20210507_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20210512_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20210513_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20210601_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20210611_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20210727_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20210728_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20210730_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20211008_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20211009_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20211022_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20211107_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20211128_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20211215_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20220113_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20220125_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20220302_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20220304_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20220307_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20220321_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20220401_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20220420_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20220425_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20220607_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20220613_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20220722_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20220723_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20220727_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20220731_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20220813_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20220815_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20220816_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20220922_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20170330_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20170405_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20170410_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20170504_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20170505_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20170702_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20170910_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20171006_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20171007_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20171101_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20171102_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20171103_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20180306_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20180329_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20180507_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20180510_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20180523_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20180527_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20180704_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20180705_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20180728_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20180801_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20180911_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20181002_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20181010_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20181125_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20181206_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20190108_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20190112_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20190311_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20190322_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20190423_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20190509_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20190527_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20190616_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20190626_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20191008_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20191023_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20191025_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20191112_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20191115_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20191121_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20191209_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20191220_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20200102_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20200128_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20200129_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20200222_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20200530_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20200607_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20200618_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20200620_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20200815_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20200819_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20200821_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20200902_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20200905_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20200909_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20200911_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20200930_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20201114_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20201117_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20201230_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20210116_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20210201_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20210318_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20210415_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20210417_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20210418_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20210516_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20210529_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20210611_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20210614_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20210803_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20211011_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20211025_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20211211_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20211216_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20220111_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20220126_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20220327_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20220509_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20220511_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20220612_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20210118_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20210130_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20210131_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20210402_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20210409_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20210608_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20210801_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20211106_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20211126_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20211127_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:38 - Data in ut20220110_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20220123_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20220124_geminiN_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20160111_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20160114_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20160119_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20160216_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20160223_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20160303_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20160330_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20160409_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20160410_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20160608_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20160721_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20160731_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20160810_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20160910_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20160927_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20161001_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20161109_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20161230_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20170306_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20170331_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20170422_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20170501_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20170701_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20170802_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20170917_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20171019_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20171028_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20171109_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20171120_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20171203_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20171216_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20171224_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20180116_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20180215_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20180223_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20180316_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20180420_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20180627_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20180629_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20180903_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20181017_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20181102_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20181204_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20181206_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20181211_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20181224_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20190106_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20190109_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20190114_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20190126_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20190213_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20190310_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20190414_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20190429_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20190510_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20190626_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20190716_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20190901_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20190922_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20191106_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20191110_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20191111_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20191205_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20191222_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20200106_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20200111_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20200219_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20201025_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20201112_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20201116_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20201120_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20201214_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20201217_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20210108_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20210216_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20210420_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20210612_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20210716_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20211007_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20211028_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20211125_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20211216_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20220106_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20220108_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20220123_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20220313_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20220404_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20220514_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20220613_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20220827_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20220914_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20221019_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20221024_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20221127_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20221221_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20230120_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20150115_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20150119_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20150213_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20150305_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20150422_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20150427_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20150606_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20150905_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20150911_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20151122_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20151207_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20151226_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20160112_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20160122_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20160204_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20160223_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20160401_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20160410_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20160801_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20160904_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20161108_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20161225_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20170206_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20170301_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20170327_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20170328_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20170427_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20170630_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20170711_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20170802_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20170827_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20170917_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20171027_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20171110_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20171226_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20171228_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20180215_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20180317_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20180328_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20180412_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20180518_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20180711_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20180903_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20180905_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20181016_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20181108_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20181202_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20190105_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20190214_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20190402_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20190413_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20190712_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20190809_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20190901_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20190929_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20191008_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20191106_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20191110_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20191120_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20200101_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20200220_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20201026_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20201115_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20201213_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20201217_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20210109_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20210116_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20210216_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20210407_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20210518_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20210611_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20210715_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20211022_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20211204_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20220105_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20220314_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20220403_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20220515_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20220612_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20220707_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20220828_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20220902_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20221020_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20221023_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20221121_geminiS_twiskyflat already processed.
# 2023-02-26 08:43:39 - Data in ut20221221_geminiS_twiskyflat already processed.
# Directory /volumes/Fantom12a/BackupData/gemini/data_calib/GMOS-S_TwilightFlats_20150101_present/GMOS-S_Twilight_Flats_r/ut20230210_geminiS_twiskyflat/procfits_twiskyflat/ successfully created.
#
# 2023-02-26 08:43:39 - Decompressing and splitting data files...
# >>> Starting decompression of bz2 files in /volumes/Fantom12a/BackupData/gemini/data_calib/GMOS-S_TwilightFlats_20150101_present/GMOS-S_Twilight_Flats_r/ut20230210_geminiS_twiskyflat/rawfits_twiskyflat/...
# >>> Decompression of bz2 files complete.
# >>> Starting decompression of fz files in /volumes/Fantom12a/BackupData/gemini/data_calib/GMOS-S_TwilightFlats_20150101_present/GMOS-S_Twilight_Flats_r/ut20230210_geminiS_twiskyflat/rawfits_twiskyflat/...
# >>> Decompression of fz files complete.
# Splitting S20230210S0030.fits...
# Splitting S20230210S0031.fits...
# Splitting S20230210S0032.fits...
# Splitting S20230210S0033.fits...
# Splitting S20230210S0034.fits...
# Splitting S20230210S0035.fits...
# Splitting S20230210S0036.fits...
# Splitting S20230210S0037.fits...
# Splitting S20230210S0038.fits...
# Splitting S20230210S0039.fits...
# Splitting S20230210S0040.fits...
# Starting image statistics output...
# >>> Image statistics output complete.
#
# 2023-02-26 08:43:57 - Decompressing, filtering, and splitting bias files...
# >>> Starting decompression of bz2 files in /volumes/Fantom12a/BackupData/gemini/data_calib/GMOS-S_TwilightFlats_20150101_present/GMOS-S_Twilight_Flats_r/ut20230210_geminiS_twiskyflat/rawfits_bias/...
# >>> Decompression of bz2 files complete.
# >>> Starting decompression of fz files in /volumes/Fantom12a/BackupData/gemini/data_calib/GMOS-S_TwilightFlats_20150101_present/GMOS-S_Twilight_Flats_r/ut20230210_geminiS_twiskyflat/rawfits_bias/...
# >>> Decompression of fz files complete.
# >>> Bias frame selection complete.
# Splitting S20230210S0065.fits...
# Splitting S20230210S0066.fits...
# Splitting S20230210S0067.fits...
# Splitting S20230210S0068.fits...
# Splitting S20230210S0069.fits...
# Starting image statistics output...
# >>> Image statistics output complete.
# Starting overscan correction and trimming...
# WARNING: FITSFixedWarning: 'datfix' made the change 'Invalid parameter values: MJD-OBS and DATE-OBS are inconsistent'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Invalid parameter values: MJD-OBS and DATE-OBS are inconsistent'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Invalid parameter values: MJD-OBS and DATE-OBS are inconsistent'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Invalid parameter values: MJD-OBS and DATE-OBS are inconsistent'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Invalid parameter values: MJD-OBS and DATE-OBS are inconsistent'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Invalid parameter values: MJD-OBS and DATE-OBS are inconsistent'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Invalid parameter values: MJD-OBS and DATE-OBS are inconsistent'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Invalid parameter values: MJD-OBS and DATE-OBS are inconsistent'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Invalid parameter values: MJD-OBS and DATE-OBS are inconsistent'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Invalid parameter values: MJD-OBS and DATE-OBS are inconsistent'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Invalid parameter values: MJD-OBS and DATE-OBS are inconsistent'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Invalid parameter values: MJD-OBS and DATE-OBS are inconsistent'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Invalid parameter values: MJD-OBS and DATE-OBS are inconsistent'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Invalid parameter values: MJD-OBS and DATE-OBS are inconsistent'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Invalid parameter values: MJD-OBS and DATE-OBS are inconsistent'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Invalid parameter values: MJD-OBS and DATE-OBS are inconsistent'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Invalid parameter values: MJD-OBS and DATE-OBS are inconsistent'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Invalid parameter values: MJD-OBS and DATE-OBS are inconsistent'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Invalid parameter values: MJD-OBS and DATE-OBS are inconsistent'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Invalid parameter values: MJD-OBS and DATE-OBS are inconsistent'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Invalid parameter values: MJD-OBS and DATE-OBS are inconsistent'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Invalid parameter values: MJD-OBS and DATE-OBS are inconsistent'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Invalid parameter values: MJD-OBS and DATE-OBS are inconsistent'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Invalid parameter values: MJD-OBS and DATE-OBS are inconsistent'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Invalid parameter values: MJD-OBS and DATE-OBS are inconsistent'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Invalid parameter values: MJD-OBS and DATE-OBS are inconsistent'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Invalid parameter values: MJD-OBS and DATE-OBS are inconsistent'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Invalid parameter values: MJD-OBS and DATE-OBS are inconsistent'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Invalid parameter values: MJD-OBS and DATE-OBS are inconsistent'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Invalid parameter values: MJD-OBS and DATE-OBS are inconsistent'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Invalid parameter values: MJD-OBS and DATE-OBS are inconsistent'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Invalid parameter values: MJD-OBS and DATE-OBS are inconsistent'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Invalid parameter values: MJD-OBS and DATE-OBS are inconsistent'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Invalid parameter values: MJD-OBS and DATE-OBS are inconsistent'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Invalid parameter values: MJD-OBS and DATE-OBS are inconsistent'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Invalid parameter values: MJD-OBS and DATE-OBS are inconsistent'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Invalid parameter values: MJD-OBS and DATE-OBS are inconsistent'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Invalid parameter values: MJD-OBS and DATE-OBS are inconsistent'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Invalid parameter values: MJD-OBS and DATE-OBS are inconsistent'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Invalid parameter values: MJD-OBS and DATE-OBS are inconsistent'. [astropy.wcs.wcs]
# >>> Overscan correction and trimming complete.
# Starting median combination of bias frames...
# >>> Median combination of bias frames complete.
# Starting overscan correction and trimming...
# WARNING: FITSFixedWarning: 'datfix' made the change 'Invalid parameter values: MJD-OBS and DATE-OBS are inconsistent'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Invalid parameter values: MJD-OBS and DATE-OBS are inconsistent'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Invalid parameter values: MJD-OBS and DATE-OBS are inconsistent'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Invalid parameter values: MJD-OBS and DATE-OBS are inconsistent'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Invalid parameter values: MJD-OBS and DATE-OBS are inconsistent'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Invalid parameter values: MJD-OBS and DATE-OBS are inconsistent'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Invalid parameter values: MJD-OBS and DATE-OBS are inconsistent'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Invalid parameter values: MJD-OBS and DATE-OBS are inconsistent'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Invalid parameter values: MJD-OBS and DATE-OBS are inconsistent'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Invalid parameter values: MJD-OBS and DATE-OBS are inconsistent'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Invalid parameter values: MJD-OBS and DATE-OBS are inconsistent'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Invalid parameter values: MJD-OBS and DATE-OBS are inconsistent'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Invalid parameter values: MJD-OBS and DATE-OBS are inconsistent'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Invalid parameter values: MJD-OBS and DATE-OBS are inconsistent'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Invalid parameter values: MJD-OBS and DATE-OBS are inconsistent'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Invalid parameter values: MJD-OBS and DATE-OBS are inconsistent'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Invalid parameter values: MJD-OBS and DATE-OBS are inconsistent'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Invalid parameter values: MJD-OBS and DATE-OBS are inconsistent'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Invalid parameter values: MJD-OBS and DATE-OBS are inconsistent'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Invalid parameter values: MJD-OBS and DATE-OBS are inconsistent'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Invalid parameter values: MJD-OBS and DATE-OBS are inconsistent'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Invalid parameter values: MJD-OBS and DATE-OBS are inconsistent'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Invalid parameter values: MJD-OBS and DATE-OBS are inconsistent'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Invalid parameter values: MJD-OBS and DATE-OBS are inconsistent'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Invalid parameter values: MJD-OBS and DATE-OBS are inconsistent'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Invalid parameter values: MJD-OBS and DATE-OBS are inconsistent'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Invalid parameter values: MJD-OBS and DATE-OBS are inconsistent'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Invalid parameter values: MJD-OBS and DATE-OBS are inconsistent'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Invalid parameter values: MJD-OBS and DATE-OBS are inconsistent'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Invalid parameter values: MJD-OBS and DATE-OBS are inconsistent'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Invalid parameter values: MJD-OBS and DATE-OBS are inconsistent'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Invalid parameter values: MJD-OBS and DATE-OBS are inconsistent'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Invalid parameter values: MJD-OBS and DATE-OBS are inconsistent'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Invalid parameter values: MJD-OBS and DATE-OBS are inconsistent'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Invalid parameter values: MJD-OBS and DATE-OBS are inconsistent'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Invalid parameter values: MJD-OBS and DATE-OBS are inconsistent'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Invalid parameter values: MJD-OBS and DATE-OBS are inconsistent'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Invalid parameter values: MJD-OBS and DATE-OBS are inconsistent'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Invalid parameter values: MJD-OBS and DATE-OBS are inconsistent'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Invalid parameter values: MJD-OBS and DATE-OBS are inconsistent'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Invalid parameter values: MJD-OBS and DATE-OBS are inconsistent'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Invalid parameter values: MJD-OBS and DATE-OBS are inconsistent'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Invalid parameter values: MJD-OBS and DATE-OBS are inconsistent'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Invalid parameter values: MJD-OBS and DATE-OBS are inconsistent'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Invalid parameter values: MJD-OBS and DATE-OBS are inconsistent'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Invalid parameter values: MJD-OBS and DATE-OBS are inconsistent'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Invalid parameter values: MJD-OBS and DATE-OBS are inconsistent'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Invalid parameter values: MJD-OBS and DATE-OBS are inconsistent'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Invalid parameter values: MJD-OBS and DATE-OBS are inconsistent'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Invalid parameter values: MJD-OBS and DATE-OBS are inconsistent'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Invalid parameter values: MJD-OBS and DATE-OBS are inconsistent'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Invalid parameter values: MJD-OBS and DATE-OBS are inconsistent'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Invalid parameter values: MJD-OBS and DATE-OBS are inconsistent'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Invalid parameter values: MJD-OBS and DATE-OBS are inconsistent'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Invalid parameter values: MJD-OBS and DATE-OBS are inconsistent'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Invalid parameter values: MJD-OBS and DATE-OBS are inconsistent'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Invalid parameter values: MJD-OBS and DATE-OBS are inconsistent'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Invalid parameter values: MJD-OBS and DATE-OBS are inconsistent'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Invalid parameter values: MJD-OBS and DATE-OBS are inconsistent'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Invalid parameter values: MJD-OBS and DATE-OBS are inconsistent'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Invalid parameter values: MJD-OBS and DATE-OBS are inconsistent'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Invalid parameter values: MJD-OBS and DATE-OBS are inconsistent'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Invalid parameter values: MJD-OBS and DATE-OBS are inconsistent'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Invalid parameter values: MJD-OBS and DATE-OBS are inconsistent'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Invalid parameter values: MJD-OBS and DATE-OBS are inconsistent'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Invalid parameter values: MJD-OBS and DATE-OBS are inconsistent'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Invalid parameter values: MJD-OBS and DATE-OBS are inconsistent'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Invalid parameter values: MJD-OBS and DATE-OBS are inconsistent'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Invalid parameter values: MJD-OBS and DATE-OBS are inconsistent'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Invalid parameter values: MJD-OBS and DATE-OBS are inconsistent'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Invalid parameter values: MJD-OBS and DATE-OBS are inconsistent'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Invalid parameter values: MJD-OBS and DATE-OBS are inconsistent'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Invalid parameter values: MJD-OBS and DATE-OBS are inconsistent'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Invalid parameter values: MJD-OBS and DATE-OBS are inconsistent'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Invalid parameter values: MJD-OBS and DATE-OBS are inconsistent'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Invalid parameter values: MJD-OBS and DATE-OBS are inconsistent'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Invalid parameter values: MJD-OBS and DATE-OBS are inconsistent'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Invalid parameter values: MJD-OBS and DATE-OBS are inconsistent'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Invalid parameter values: MJD-OBS and DATE-OBS are inconsistent'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Invalid parameter values: MJD-OBS and DATE-OBS are inconsistent'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Invalid parameter values: MJD-OBS and DATE-OBS are inconsistent'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Invalid parameter values: MJD-OBS and DATE-OBS are inconsistent'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Invalid parameter values: MJD-OBS and DATE-OBS are inconsistent'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Invalid parameter values: MJD-OBS and DATE-OBS are inconsistent'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Invalid parameter values: MJD-OBS and DATE-OBS are inconsistent'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Invalid parameter values: MJD-OBS and DATE-OBS are inconsistent'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Invalid parameter values: MJD-OBS and DATE-OBS are inconsistent'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Invalid parameter values: MJD-OBS and DATE-OBS are inconsistent'. [astropy.wcs.wcs]
# >>> Overscan correction and trimming complete.
# Starting bias subtraction...
# >>> Bias subtraction complete.
# >>> Starting adjacent amp area concatenation...
# >>> Adjacent amp area concatenation complete.
# >>> Starting fpack compression of FITS files in /volumes/Fantom12a/BackupData/gemini/data_calib/GMOS-S_TwilightFlats_20150101_present/GMOS-S_Twilight_Flats_r/ut20230210_geminiS_twiskyflat/rawfits_twiskyflat/...
# >>> fpack compression of FITS files complete.
# >>> Starting fpack compression of FITS files in /volumes/Fantom12a/BackupData/gemini/data_calib/GMOS-S_TwilightFlats_20150101_present/GMOS-S_Twilight_Flats_r/ut20230210_geminiS_twiskyflat/rawfits_bias/...
# >>> fpack compression of FITS files complete.
# >>> Starting fpack compression of FITS files in /volumes/Fantom12a/BackupData/gemini/data_calib/GMOS-S_TwilightFlats_20150101_present/GMOS-S_Twilight_Flats_r/ut20230210_geminiS_twiskyflat/procfits_twiskyflat/...
# >>> fpack compression of FITS files complete.
# 2023-02-26 08:46:57 - Data in ut20170303_geminiS_twiskyflat already processed.
# 2023-02-26 08:46:57 - Data in ut20170328_geminiS_twiskyflat already processed.
# 2023-02-26 08:46:57 - Data in ut20170601_geminiS_twiskyflat already processed.
# 2023-02-26 08:46:57 - Data in ut20170702_geminiS_twiskyflat already processed.
# 2023-02-26 08:46:57 - Data in ut20170802_geminiS_twiskyflat already processed.
# 2023-02-26 08:46:57 - Data in ut20171002_geminiS_twiskyflat already processed.
# 2023-02-26 08:46:57 - Data in ut20171019_geminiS_twiskyflat already processed.
# 2023-02-26 08:46:57 - Data in ut20171028_geminiS_twiskyflat already processed.
# 2023-02-26 08:46:57 - Data in ut20171110_geminiS_twiskyflat already processed.
# 2023-02-26 08:46:57 - Data in ut20171120_geminiS_twiskyflat already processed.
# 2023-02-26 08:46:57 - Data in ut20180102_geminiS_twiskyflat already processed.
# 2023-02-26 08:46:57 - Data in ut20180219_geminiS_twiskyflat already processed.
# 2023-02-26 08:46:57 - Data in ut20180328_geminiS_twiskyflat already processed.
# 2023-02-26 08:46:57 - Data in ut20180412_geminiS_twiskyflat already processed.
# 2023-02-26 08:46:57 - Data in ut20180629_geminiS_twiskyflat already processed.
# 2023-02-26 08:46:57 - Data in ut20180906_geminiS_twiskyflat already processed.
# 2023-02-26 08:46:57 - Data in ut20181016_geminiS_twiskyflat already processed.
# 2023-02-26 08:46:57 - Data in ut20181203_geminiS_twiskyflat already processed.
# 2023-02-26 08:46:57 - Data in ut20181211_geminiS_twiskyflat already processed.
# 2023-02-26 08:46:57 - Data in ut20190105_geminiS_twiskyflat already processed.
# 2023-02-26 08:46:57 - Data in ut20190413_geminiS_twiskyflat already processed.
# 2023-02-26 08:46:57 - Data in ut20190712_geminiS_twiskyflat already processed.
# 2023-02-26 08:46:57 - Data in ut20190918_geminiS_twiskyflat already processed.
# 2023-02-26 08:46:57 - Data in ut20190929_geminiS_twiskyflat already processed.
# 2023-02-26 08:46:57 - Data in ut20191116_geminiS_twiskyflat already processed.
# 2023-02-26 08:46:57 - Data in ut20191227_geminiS_twiskyflat already processed.
# 2023-02-26 08:46:57 - Data in ut20191231_geminiS_twiskyflat already processed.
# 2023-02-26 08:46:57 - Data in ut20200218_geminiS_twiskyflat already processed.
# 2023-02-26 08:46:57 - Data in ut20201026_geminiS_twiskyflat already processed.
# 2023-02-26 08:46:57 - Data in ut20201129_geminiS_twiskyflat already processed.
# 2023-02-26 08:46:57 - Data in ut20201213_geminiS_twiskyflat already processed.
# 2023-02-26 08:46:57 - Data in ut20201217_geminiS_twiskyflat already processed.
# 2023-02-26 08:46:57 - Data in ut20210116_geminiS_twiskyflat already processed.
# 2023-02-26 08:46:57 - Data in ut20210213_geminiS_twiskyflat already processed.
# 2023-02-26 08:46:57 - Data in ut20210217_geminiS_twiskyflat already processed.
# 2023-02-26 08:46:57 - Data in ut20210517_geminiS_twiskyflat already processed.
# 2023-02-26 08:46:57 - Data in ut20210603_geminiS_twiskyflat already processed.
# 2023-02-26 08:46:57 - Data in ut20210611_geminiS_twiskyflat already processed.
# 2023-02-26 08:46:57 - Data in ut20210719_geminiS_twiskyflat already processed.
# 2023-02-26 08:46:57 - Data in ut20211025_geminiS_twiskyflat already processed.
# 2023-02-26 08:46:57 - Data in ut20211206_geminiS_twiskyflat already processed.
# 2023-02-26 08:46:57 - Data in ut20211223_geminiS_twiskyflat already processed.
# 2023-02-26 08:46:57 - Data in ut20220106_geminiS_twiskyflat already processed.
# 2023-02-26 08:46:57 - Data in ut20220314_geminiS_twiskyflat already processed.
# 2023-02-26 08:46:57 - Data in ut20220404_geminiS_twiskyflat already processed.
# 2023-02-26 08:46:57 - Data in ut20220514_geminiS_twiskyflat already processed.
# 2023-02-26 08:46:57 - Data in ut20220611_geminiS_twiskyflat already processed.
# 2023-02-26 08:46:57 - Data in ut20220704_geminiS_twiskyflat already processed.
# 2023-02-26 08:46:57 - Data in ut20220829_geminiS_twiskyflat already processed.
# 2023-02-26 08:46:57 - Data in ut20220903_geminiS_twiskyflat already processed.
# 2023-02-26 08:46:57 - Data in ut20221021_geminiS_twiskyflat already processed.
# 2023-02-26 08:46:57 - Data in ut20221105_geminiS_twiskyflat already processed.
# 2023-02-26 08:46:57 - Data in ut20230103_geminiS_twiskyflat already processed.
# 2023-02-26 08:46:57 - Data in ut20210117_geminiS_twiskyflat already processed.
# 2023-02-26 08:46:57 - Data in ut20210218_geminiS_twiskyflat already processed.
# 2023-02-26 08:46:57 - Data in ut20210613_geminiS_twiskyflat already processed.
# 2023-02-26 08:46:57 - Data in ut20210719_geminiS_twiskyflat already processed.
# 2023-02-26 08:46:57 - Data in ut20211022_geminiS_twiskyflat already processed.
# 2023-02-26 08:46:57 - Data in ut20220119_geminiS_twiskyflat already processed.
# 2023-02-26 08:46:57 - Data in ut20220316_geminiS_twiskyflat already processed.
# 2023-02-26 08:46:57 - Data in ut20220403_geminiS_twiskyflat already processed.
# 2023-02-26 08:46:57 - Data in ut20220516_geminiS_twiskyflat already processed.
# 2023-02-26 08:46:57 - Data in ut20220905_geminiS_twiskyflat already processed.
# 2023-02-26 08:46:57 - Data in ut20221021_geminiS_twiskyflat already processed.
# 2023-02-26 08:46:57 - Data in ut20221104_geminiS_twiskyflat already processed.
# 2023-02-26 08:46:57 - Data in ut20221229_geminiS_twiskyflat already processed.
# Done.
